# %%
import pandas as pd

# %%
df=pd.read_csv('updat.csv')
df.head()

# %%
def lalong(location):
    lat=0
    lon=0
    num=0
    if(location=='Guwahati'):
        lat=26.148043
        lon=91.731377
        num=1
    if(location=='Hyderabad'):
        lat=17.387140 
        lon=78.491684
        num=2
    if(location=='Delhi'):
        lat=28.653229 
        lon=77.308601
        num=3
    if(location=='Chandigarh'):
        lat=30.741482 
        lon=76.768066
        num=4
    if(location=='Jaipur'):
        lat=26.922070 
        lon=75.778885
        num=5
    if(location=='Nagpur'):
        lat=21.146633 
        lon=79.088860
        num=6
    if(location=='Kolkata'):
        lat=22.572645 
        lon=88.363892
        num=7
    if(location=='Kanpur'):
        lat=26.449923 
        lon=80.331871
        num=8
    if(location=='Agra'):
        lat=27.176670
        lon=78.008072
        num=9
    if(location=='Kochi'):
        lat=9.939093 
        lon=76.270523
        num=10
    if(location=='Vishakapatnam'):
        lat=17.686815 
        lon=83.218483
        num=11
    if(location=='Bangalore'):
        lat=12.972442 
        lon=77.580643
        num=12
    if(location=='Chennai'):
        lat=13.067439 
        lon=80.237617
        num=13
    if(location=='Ahmedabad'):
        lat=23.033863 
        lon=72.585022
        num=14
    if(location=='Lucknow'):
        lat=26.850000 
        lon=80.949997
        num=15
    if(location=='Ludhiana'):
        lat=30.900965 
        lon=75.857277
        num=16
    if(location=='Jodhpur'):
        lat=26.263863 
        lon=73.008957
        num=17
    if(location=='Navi Mumbai'):
        lat=19.076090 
        lon=72.877426
        num=18
    if(location=='Pune'):
        lat=18.516726 
        lon=73.856255
        num=19
    if(location=='Nashik'):
        lat=19.997454 
        lon=73.789803
        num=20
    if(location=='Kota'):
        lat=25.1695181 
        lon=75.854838
        num=21
    if(location=='Gobindgarh'):
        lat=30.663738 
        lon=76.300042
        num=22
    if(location=='Jalandhar'):
        lat=31.326015 
        lon=75.576180
        num=23
    if(location=='Alwar'):
        lat=27.560932
        lon=76.625015
        num=24
    if(location=='Udaipur'):
        lat=24.571270 
        lon=73.691544
        num=25
    if(location=='Thane'):
        lat=19.218330
        lon=72.978088
        num=26
    if(location=='Howrah'):
        lat=22.595770 
        lon=88.263641
        num=27
    if(location=='Parwanoo'):
        lat=30.8381 
        lon=76.9585
        num=28
    if(location=='Aizwal'):
        lat=23.727106 
        lon=92.717636
        num=29
    if(location=='DANKUNI'):
        lat=22.671679 
        lon=88.300209
        num=30
    if(location=='Faridkot'):
        lat=30.678186 
        lon=74.739555
        num=31
    if(location=='Kothur'):
        lat=17.1474 
        lon=78.2889
        num=32
    if(location=='Hoshiarpur'):
        lat=31.527355 
        lon=75.913673
        num=33
    if(location=='Bidar'):
        lat=17.920000 
        lon=77.519722
        num=34
    if(location=='Mathura'):
        lat=27.492413  
        lon=77.673676
        num=35
    if(location=='Konark'):
        lat=20.021883 
        lon=73.849785
        num=36
    if(location=='Chandarpur'):
        lat=19.970324
        lon=79.303360
        num=37
    if(location=='Imphal'):
        lat=24.813967 
        lon=93.950279
        num=38
    if(location=='Keonjhar'):
        lat=21.628933 
        lon=85.581688
        num=39
    if(location=='Silchar'):
        lat=24.833946 
        lon=92.779282
        num=40
    if(location=='Umsning'):
        lat=25.752899 
        lon=91.894455
        num=41
    if(location=='Bijapur'):
        lat=16.827545 
        lon=75.725327
        num=42
    if(location=='Puri'):
        lat=19.817743 
        lon=85.828629
        num=43
    if(location=='MORBI'):
        lat=22.811989 
        lon=70.823616
        num=44
    if(location=='Saharanpur'):
        lat=29.959694 
        lon=77.549057
        num=45
    if(location=='Baruipur'):
        lat=22.3668 
        lon=88.4373
        num=46
    if(location=='Naharlagun'):
        lat=27.1046 
        lon=93.6953
        num=47
    if(location=='Itanagar'):
        lat=27.0869 
        lon=93.6086
        num=48
    if(location=='Tuticorin'):
        lat=8.7642
        lon=78.1348
        num=49
    if(location=='Chittorgarh'):
        lat=24.879999 
        lon=74.629997
        num=50
    if(location=='Noida'):
        lat=28.535517 
        lon=77.391029
        num=51
    if(location=='Ghaziabad'):
        lat=28.6692
        lon=77.4538
        num=52
    if(location=='Nizamabad'):
        lat=18.6725 
        lon=78.0941
        num=53
    if(location=='VAPI'):
        lat=20.385181 
        lon=72.911453
        num=54
    if(location=='Sarigam'):
        lat=20.290300 
        lon=72.852700
        num=55
    if(location=='Bhuj'):
        lat=23.265671 
        lon=69.676903
        num=56
    if(location=='SANAND'):
        lat=22.982460 
        lon=72.378578
        num=57
    if(location=='Khajuraho'):
        lat=24.851900 
        lon=79.923000
        num=58
    if(location=='Gangtok'):
        lat=27.325757 
        lon=88.698277
        num=59
    if(location=='Dharuhera'):
        lat=28.205523 
        lon=76.795311
        num=60
    return lat

# %%
df['latitude']=df['location'].apply(lalong)
data= df[['latitude','location']]
data.head()
# Out:
#    latitude   location
# 0  17.38714  Hyderabad
# 1  17.38714  Hyderabad
# 2  17.38714  Hyderabad
# 3  17.38714  Hyderabad
# 4  17.38714  Hyderabad

# %%
def lalong(location):
    lat=0
    lon=0
    num=0
    if(location=='Guwahati'):
        lat=26.148043
        lon=91.731377
        num=1
    if(location=='Hyderabad'):
        lat=17.387140 
        lon=78.491684
        num=2
    if(location=='Delhi'):
        lat=28.653229 
        lon=77.308601
        num=3
    if(location=='Chandigarh'):
        lat=30.741482 
        lon=76.768066
        num=4
    if(location=='Jaipur'):
        lat=26.922070 
        lon=75.778885
        num=5
    if(location=='Nagpur'):
        lat=21.146633 
        lon=79.088860
        num=6
    if(location=='Kolkata'):
        lat=22.572645 
        lon=88.363892
        num=7
    if(location=='Kanpur'):
        lat=26.449923 
        lon=80.331871
        num=8
    if(location=='Agra'):
        lat=27.176670
        lon=78.008072
        num=9
    if(location=='Kochi'):
        lat=9.939093 
        lon=76.270523
        num=10
    if(location=='Vishakapatnam'):
        lat=17.686815 
        lon=83.218483
        num=11
    if(location=='Bangalore'):
        lat=12.972442 
        lon=77.580643
        num=12
    if(location=='Chennai'):
        lat=13.067439 
        lon=80.237617
        num=13
    if(location=='Ahmedabad'):
        lat=23.033863 
        lon=72.585022
        num=14
    if(location=='Lucknow'):
        lat=26.850000 
        lon=80.949997
        num=15
    if(location=='Ludhiana'):
        lat=30.900965 
        lon=75.857277
        num=16
    if(location=='Jodhpur'):
        lat=26.263863 
        lon=73.008957
        num=17
    if(location=='Navi Mumbai'):
        lat=19.076090 
        lon=72.877426
        num=18
    if(location=='Pune'):
        lat=18.516726 
        lon=73.856255
        num=19
    if(location=='Nashik'):
        lat=19.997454 
        lon=73.789803
        num=20
    if(location=='Kota'):
        lat=25.1695181 
        lon=75.854838
        num=21
    if(location=='Gobindgarh'):
        lat=30.663738 
        lon=76.300042
        num=22
    if(location=='Jalandhar'):
        lat=31.326015 
        lon=75.576180
        num=23
    if(location=='Alwar'):
        lat=27.560932
        lon=76.625015
        num=24
    if(location=='Udaipur'):
        lat=24.571270 
        lon=73.691544
        num=25
    if(location=='Thane'):
        lat=19.218330
        lon=72.978088
        num=26
    if(location=='Howrah'):
        lat=22.595770 
        lon=88.263641
        num=27
    if(location=='Parwanoo'):
        lat=30.8381 
        lon=76.9585
        num=28
    if(location=='Aizwal'):
        lat=23.727106 
        lon=92.717636
        num=29
    if(location=='DANKUNI'):
        lat=22.671679 
        lon=88.300209
        num=30
    if(location=='Faridkot'):
        lat=30.678186 
        lon=74.739555
        num=31
    if(location=='Kothur'):
        lat=17.1474 
        lon=78.2889
        num=32
    if(location=='Hoshiarpur'):
        lat=31.527355 
        lon=75.913673
        num=33
    if(location=='Bidar'):
        lat=17.920000 
        lon=77.519722
        num=34
    if(location=='Mathura'):
        lat=27.492413  
        lon=77.673676
        num=35
    if(location=='Konark'):
        lat=20.021883 
        lon=73.849785
        num=36
    if(location=='Chandarpur'):
        lat=19.970324
        lon=79.303360
        num=37
    if(location=='Imphal'):
        lat=24.813967 
        lon=93.950279
        num=38
    if(location=='Keonjhar'):
        lat=21.628933 
        lon=85.581688
        num=39
    if(location=='Silchar'):
        lat=24.833946 
        lon=92.779282
        num=40
    if(location=='Umsning'):
        lat=25.752899 
        lon=91.894455
        num=41
    if(location=='Bijapur'):
        lat=16.827545 
        lon=75.725327
        num=42
    if(location=='Puri'):
        lat=19.817743 
        lon=85.828629
        num=43
    if(location=='MORBI'):
        lat=22.811989 
        lon=70.823616
        num=44
    if(location=='Saharanpur'):
        lat=29.959694 
        lon=77.549057
        num=45
    if(location=='Baruipur'):
        lat=22.3668 
        lon=88.4373
        num=46
    if(location=='Naharlagun'):
        lat=27.1046 
        lon=93.6953
        num=47
    if(location=='Itanagar'):
        lat=27.0869 
        lon=93.6086
        num=48
    if(location=='Tuticorin'):
        lat=8.7642
        lon=78.1348
        num=49
    if(location=='Chittorgarh'):
        lat=24.879999 
        lon=74.629997
        num=50
    if(location=='Noida'):
        lat=28.535517 
        lon=77.391029
        num=51
    if(location=='Ghaziabad'):
        lat=28.6692
        lon=77.4538
        num=52
    if(location=='Nizamabad'):
        lat=18.6725 
        lon=78.0941
        num=53
    if(location=='VAPI'):
        lat=20.385181 
        lon=72.911453
        num=54
    if(location=='Sarigam'):
        lat=20.290300 
        lon=72.852700
        num=55
    if(location=='Bhuj'):
        lat=23.265671 
        lon=69.676903
        num=56
    if(location=='SANAND'):
        lat=22.982460 
        lon=72.378578
        num=57
    if(location=='Khajuraho'):
        lat=24.851900 
        lon=79.923000
        num=58
    if(location=='Gangtok'):
        lat=27.325757 
        lon=88.698277
        num=59
    if(location=='Dharuhera'):
        lat=28.205523 
        lon=76.795311
        num=60
    return lon

# %%
df['longitude']=df['location'].apply(lalong)
data= df[['longitude','location']]
data.head()
# Out:
#    longitude   location
# 0  78.491684  Hyderabad
# 1  78.491684  Hyderabad
# 2  78.491684  Hyderabad
# 3  78.491684  Hyderabad
# 4  78.491684  Hyderabad

# %%
def lalong(location):
    lat=0
    lon=0
    num=0
    if(location=='Guwahati'):
        lat=26.148043
        lon=91.731377
        num=1
    if(location=='Hyderabad'):
        lat=17.387140 
        lon=78.491684
        num=2
    if(location=='Delhi'):
        lat=28.653229 
        lon=77.308601
        num=3
    if(location=='Chandigarh'):
        lat=30.741482 
        lon=76.768066
        num=4
    if(location=='Jaipur'):
        lat=26.922070 
        lon=75.778885
        num=5
    if(location=='Nagpur'):
        lat=21.146633 
        lon=79.088860
        num=6
    if(location=='Kolkata'):
        lat=22.572645 
        lon=88.363892
        num=7
    if(location=='Kanpur'):
        lat=26.449923 
        lon=80.331871
        num=8
    if(location=='Agra'):
        lat=27.176670
        lon=78.008072
        num=9
    if(location=='Kochi'):
        lat=9.939093 
        lon=76.270523
        num=10
    if(location=='Vishakapatnam'):
        lat=17.686815 
        lon=83.218483
        num=11
    if(location=='Bangalore'):
        lat=12.972442 
        lon=77.580643
        num=12
    if(location=='Chennai'):
        lat=13.067439 
        lon=80.237617
        num=13
    if(location=='Ahmedabad'):
        lat=23.033863 
        lon=72.585022
        num=14
    if(location=='Lucknow'):
        lat=26.850000 
        lon=80.949997
        num=15
    if(location=='Ludhiana'):
        lat=30.900965 
        lon=75.857277
        num=16
    if(location=='Jodhpur'):
        lat=26.263863 
        lon=73.008957
        num=17
    if(location=='Navi Mumbai'):
        lat=19.076090 
        lon=72.877426
        num=18
    if(location=='Pune'):
        lat=18.516726 
        lon=73.856255
        num=19
    if(location=='Nashik'):
        lat=19.997454 
        lon=73.789803
        num=20
    if(location=='Kota'):
        lat=25.1695181 
        lon=75.854838
        num=21
    if(location=='Gobindgarh'):
        lat=30.663738 
        lon=76.300042
        num=22
    if(location=='Jalandhar'):
        lat=31.326015 
        lon=75.576180
        num=23
    if(location=='Alwar'):
        lat=27.560932
        lon=76.625015
        num=24
    if(location=='Udaipur'):
        lat=24.571270 
        lon=73.691544
        num=25
    if(location=='Thane'):
        lat=19.218330
        lon=72.978088
        num=26
    if(location=='Howrah'):
        lat=22.595770 
        lon=88.263641
        num=27
    if(location=='Parwanoo'):
        lat=30.8381 
        lon=76.9585
        num=28
    if(location=='Aizwal'):
        lat=23.727106 
        lon=92.717636
        num=29
    if(location=='DANKUNI'):
        lat=22.671679 
        lon=88.300209
        num=30
    if(location=='Faridkot'):
        lat=30.678186 
        lon=74.739555
        num=31
    if(location=='Kothur'):
        lat=17.1474 
        lon=78.2889
        num=32
    if(location=='Hoshiarpur'):
        lat=31.527355 
        lon=75.913673
        num=33
    if(location=='Bidar'):
        lat=17.920000 
        lon=77.519722
        num=34
    if(location=='Mathura'):
        lat=27.492413  
        lon=77.673676
        num=35
    if(location=='Konark'):
        lat=20.021883 
        lon=73.849785
        num=36
    if(location=='Chandarpur'):
        lat=19.970324
        lon=79.303360
        num=37
    if(location=='Imphal'):
        lat=24.813967 
        lon=93.950279
        num=38
    if(location=='Keonjhar'):
        lat=21.628933 
        lon=85.581688
        num=39
    if(location=='Silchar'):
        lat=24.833946 
        lon=92.779282
        num=40
    if(location=='Umsning'):
        lat=25.752899 
        lon=91.894455
        num=41
    if(location=='Bijapur'):
        lat=16.827545 
        lon=75.725327
        num=42
    if(location=='Puri'):
        lat=19.817743 
        lon=85.828629
        num=43
    if(location=='MORBI'):
        lat=22.811989 
        lon=70.823616
        num=44
    if(location=='Saharanpur'):
        lat=29.959694 
        lon=77.549057
        num=45
    if(location=='Baruipur'):
        lat=22.3668 
        lon=88.4373
        num=46
    if(location=='Naharlagun'):
        lat=27.1046 
        lon=93.6953
        num=47
    if(location=='Itanagar'):
        lat=27.0869 
        lon=93.6086
        num=48
    if(location=='Tuticorin'):
        lat=8.7642
        lon=78.1348
        num=49
    if(location=='Chittorgarh'):
        lat=24.879999 
        lon=74.629997
        num=50
    if(location=='Noida'):
        lat=28.535517 
        lon=77.391029
        num=51
    if(location=='Ghaziabad'):
        lat=28.6692
        lon=77.4538
        num=52
    if(location=='Nizamabad'):
        lat=18.6725 
        lon=78.0941
        num=53
    if(location=='VAPI'):
        lat=20.385181 
        lon=72.911453
        num=54
    if(location=='Sarigam'):
        lat=20.290300 
        lon=72.852700
        num=55
    if(location=='Bhuj'):
        lat=23.265671 
        lon=69.676903
        num=56
    if(location=='SANAND'):
        lat=22.982460 
        lon=72.378578
        num=57
    if(location=='Khajuraho'):
        lat=24.851900 
        lon=79.923000
        num=58
    if(location=='Gangtok'):
        lat=27.325757 
        lon=88.698277
        num=59
    if(location=='Dharuhera'):
        lat=28.205523 
        lon=76.795311
        num=60
    return num

# %%
df['Number']=df['location'].apply(lalong)
data= df[['Number','location']]
data.head()
# Out:
#    Number   location
# 0       2  Hyderabad
# 1       2  Hyderabad
# 2       2  Hyderabad
# 3       2  Hyderabad
# 4       2  Hyderabad

# %%
df.to_csv('upedit.csv')

# %%
df=df[df.latitude!=0]

# %%
df
# Out:
#                  state     location type    so2     no2        rspm  \
# 0       Andhra Pradesh    Hyderabad  RRO   3.90   14.10  108.833091
# 1       Andhra Pradesh    Hyderabad    I   5.60   11.80  108.833091
# 2       Andhra Pradesh    Hyderabad  RRO   3.30   19.30  108.833091
# 3       Andhra Pradesh    Hyderabad  RRO   3.90    8.20  108.833091
# 4       Andhra Pradesh    Hyderabad  RRO   3.50   12.10  108.833091
# 5       Andhra Pradesh    Hyderabad    I   7.90   10.20  108.833091
# 6       Andhra Pradesh    Hyderabad    I  12.40   11.50  108.833091
# 7       Andhra Pradesh    Hyderabad  RRO   4.00   12.30  108.833091
# 8       Andhra Pradesh    Hyderabad  RRO   6.30   11.50  108.833091
# 9       Andhra Pradesh    Hyderabad    I  44.80   13.70  108.833091
# 10      Andhra Pradesh    Hyderabad  RRO   8.10   17.80  108.833091
# 11      Andhra Pradesh    Hyderabad  RRO   7.70   11.30  108.833091
# 12      Andhra Pradesh    Hyderabad    I  20.60   13.60  108.833091
# ...

# %%
mydf=df[df.Condition=='Hazardous']

# %%
mydf
# Out:
#                  state   location type    so2    no2        rspm        spm  \
# 8       Andhra Pradesh  Hyderabad  RRO    6.3   11.5  108.833091  270.00000
# 15      Andhra Pradesh  Hyderabad  RRO   22.3   35.9  108.833091  255.00000
# 19      Andhra Pradesh  Hyderabad  RRO   24.5   18.0  108.833091  330.00000
# 21      Andhra Pradesh  Hyderabad  RRO    5.2   41.3  108.833091  287.00000
# 23      Andhra Pradesh  Hyderabad  RRO    9.7   12.4  108.833091  283.00000
# 44      Andhra Pradesh  Hyderabad  RRO   20.0   64.6  108.833091  353.00000
# 45      Andhra Pradesh  Hyderabad  RRO   35.8   12.5  108.833091  261.00000
# 49      Andhra Pradesh  Hyderabad  RRO    6.0   34.1  108.833091  271.00000
# 56      Andhra Pradesh  Hyderabad  RRO   24.9   61.0  108.833091  276.00000
# 63      Andhra Pradesh  Hyderabad  RRO   12.4   38.0  108.833091  267.00000
# 92      Andhra Pradesh  Hyderabad  RRO   17.4   31.7  108.833091  264.00000
# ...

# %%
mydf.to_csv('azzar.csv')

# %%
# making data frame from csv file 
df = pd.read_csv("azzar.csv") 
# sorting by first name 
df=df.drop_duplicates(subset="location")

# %%
df.head()
# Out:
#       Unnamed: 0           state    location type   so2   no2        rspm  \
# 0              8  Andhra Pradesh   Hyderabad  RRO   6.3  11.5  108.833091
# 2279        8441           Assam    Guwahati  RRO  15.7  46.1  108.833091
# 3030       13158           Assam     Silchar   RO   5.8  16.3  207.000000
# 3039       14662      Chandigarh  Chandigarh    I  11.3  29.7  108.833091
# 4344       21134           Delhi       Delhi    R   8.6  16.2  108.833091
#
#         spm      pm2_5       date   ...        si      ni         rpi     spi  \
# 0     270.0  40.791467   9/1/1990   ...     7.875  14.375  109.611030  220.00
# 2279  330.0  40.791467  10/1/1993   ...    19.625  90.125  109.611030  280.00
# 3030  383.0  40.791467   2/4/2009   ...     7.250  20.375  142.333333  341.25
# 3039  318.0  40.791467   5/1/1989   ...    14.125  37.125  109.611030  268.00
# 4344  323.0  40.791467   1/9/1987   ...    10.750  20.250  109.611030  273.00
#
# ...

# %%
df.to_csv('plmap.csv')
