# %%
import pandas as pd

# %%
df=pd.read_csv('cond.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1       sampling_date           state   location  \
# 0           0             0  February - M021990  Andhra Pradesh  Hyderabad
# 1           1             1  February - M021990  Andhra Pradesh  Hyderabad
# 2           2             2  February - M021990  Andhra Pradesh  Hyderabad
# 3           3             3     March - M031990  Andhra Pradesh  Hyderabad
# 4           4             4     March - M031990  Andhra Pradesh  Hyderabad
#
#                                  type  so2   no2        rspm        spm  \
# 0  Residential, Rural and other Areas  4.8  17.4  108.832784  220.78348
# 1                     Industrial Area  3.1   7.0  108.832784  220.78348
# 2  Residential, Rural and other Areas  6.2  28.5  108.832784  220.78348
# 3  Residential, Rural and other Areas  6.3  14.7  108.832784  220.78348
# 4                     Industrial Area  4.7   7.5  108.832784  220.78348
#
#   location_monitoring_station     si      ni         rpi        spi  AQI  \
# ...

# %%
data=df['Condition'].value_counts()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-fe157005b23d> in <module>
#       1 data.head()
# ----> 2 df = df['Condition'].drop_duplicates()
#       3 df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ...

# %%
df.head()
# Out:
# 0       Very Unhealthy
# 11           Unhealthy
# 20           Hazardous
# 1090              Good
# 1169          Moderate
# Name: Condition, dtype: object

# %%
df
# Out:
#         Unnamed: 0  Unnamed: 0.1        sampling_date           state  \
# 11              11            11       June - M061990  Andhra Pradesh
# 12              12            12       June - M061990  Andhra Pradesh
# 13              13            13       June - M061990  Andhra Pradesh
# 14              14            14       July - M071990  Andhra Pradesh
# 15              15            15       July - M071990  Andhra Pradesh
# 16              16            16       July - M071990  Andhra Pradesh
# 18              18            18     August - M081990  Andhra Pradesh
# 19              19            19     August - M081990  Andhra Pradesh
# 20              20            20  September - M091990  Andhra Pradesh
# 21              21            21  September - M091990  Andhra Pradesh
# 22              22            22  September - M091990  Andhra Pradesh
# 23              23            23    October - M101990  Andhra Pradesh
# ...

# %%
dataa=df['Condition'].value_counts()

# %%
dataa
# Out:
# Hazardous    68569
# Unhealthy    58885
# Good         17117
# Moderate     15078
# Name: Condition, dtype: int64
